# %%
# To calculate Speed and Azimuth of a mid point Midpoint (Lon, Lat) in excel.
print("Hey Nishant")
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os

# Convert decimal degrees to DMS format
def decimal_to_dms(dd, is_lat=True):
    direction = ''
    if is_lat:
        direction = 'N' if dd >= 0 else 'S'
    else:
        direction = 'E' if dd >= 0 else 'W'
    dd = abs(dd)
    degrees = int(dd)
    minutes = int((dd - degrees) * 60)
    seconds = round((dd - degrees - minutes / 60) * 3600)
    return degrees, minutes, seconds, direction

# Get result from GAGE calculator for a lat/lon pair
def get_motion_result(lat_dd, lon_dd):
    lat_d, lat_m, lat_s, lat_dir = decimal_to_dms(lat_dd, is_lat=True)
    lon_d, lon_m, lon_s, lon_dir = decimal_to_dms(lon_dd, is_lat=False)

    data = {
        "lat": lat_d,
        "lat_m": lat_m,
        "lat_s": lat_s,
        "lon": lon_d,
        "lon_m": lon_m,
        "lon_s": lon_s,
        "model": "itrf2020",
        "reference": "NNR",
        "format": "html",
        "submit": "Submit"
    }

    response = requests.post("https://www.unavco.org/software/geodetic-utilities/plate-motion-calculator/plate-motion/model", data=data)
    soup = BeautifulSoup(response.text, "html.parser")
    table = soup.find("table")
    if not table:
        return None

    rows = table.find_all("tr")
    if len(rows) < 2:
        return None

    values = [td.text.strip().replace('\xa0', '') for td in rows[1].find_all("td")]

    return {
        "Latitude (Decimal)": lat_dd,
        "Longitude (Decimal)": lon_dd,
        "Latitude (DMS)": f"{lat_d}° {lat_m}' {lat_s}\" {lat_dir}",
        "Longitude (DMS)": f"{lon_d}° {lon_m}' {lon_s}\" {lon_dir}",
        "Speed (mm/yr)": float(values[3]),
        "Azimuth (°)": float(values[4].replace("°", "")),
        "North Velocity (mm/yr)": float(values[5]),
        "East Velocity (mm/yr)": float(values[6]),
        "Plate": values[7]
    }

# === CONFIGURATION ===
input_file = r"C:\Users\mainw\Downloads\ridges-midpoint.xlsx"
output_folder = r"C:\Users\mainw\Downloads"
output_file = os.path.join(output_folder, "GAGE_Output.xlsx")

# === PROCESSING ===
df_input = pd.read_excel(input_file)

results = []
for index, row in df_input.iterrows():
    try:
        lon_str, lat_str = row["Midpoint (Lon, Lat)"].strip("()").split(",")
        lon = float(lon_str)
        lat = float(lat_str)
        print(f"📍 Processing Row {index + 1}: Latitude = {lat:.6f}, Longitude = {lon:.6f} ...")
        result = get_motion_result(lat, lon)
        if result:
            results.append(result)
            print(f"✅ Success: Speed = {result['Speed (mm/yr)']} mm/yr, Azimuth = {result['Azimuth (°)']}°\n")
        else:
            print(f"⚠️ No result returned from GAGE for row {index + 1}\n")
    except Exception as e:
        print(f"❌ Error processing row {index + 1}: {e}\n")

# Save output
df_output = pd.DataFrame(results)
df_output.to_excel(output_file, index=False)
print(f"✅ All done! Results saved to:\n{output_file}")
# Out:
# Hey Nishant
# 📍 Processing Row 1: Latitude = -16.431723, Longitude = 67.151206 ...
# ✅ Success: Speed = 50.52 mm/yr, Azimuth = 50.35°
#
# 📍 Processing Row 2: Latitude = -15.719582, Longitude = 67.437041 ...
# ✅ Success: Speed = 50.84 mm/yr, Azimuth = 50.55°
#
# 📍 Processing Row 3: Latitude = 6.033978, Longitude = 68.439295 ...
# ✅ Success: Speed = 53.94 mm/yr, Azimuth = 52.89°
#
# 📍 Processing Row 4: Latitude = -13.087517, Longitude = 66.650260 ...
# ✅ Success: Speed = 51.52 mm/yr, Azimuth = 51.44°
#
# 📍 Processing Row 5: Latitude = -13.482451, Longitude = 66.662688 ...
# ✅ Success: Speed = 51.39 mm/yr, Azimuth = 51.32°
#
# 📍 Processing Row 6: Latitude = -11.083771, Longitude = 66.276616 ...
# ✅ Success: Speed = 52.06 mm/yr, Azimuth = 52.04°
#
# 📍 Processing Row 7: Latitude = -11.451832, Longitude = 66.405707 ...
# ✅ Success: Speed = 51.98 mm/yr, Azimuth = 51.93°
#
# 📍 Processing Row 8: Latitude = -9.448784, Longitude = 67.010870 ...
# ✅ Success: Speed = 52.73 mm/yr, Azimuth = 52.35°
#
# 📍 Processing Row 9: Latitude = -8.464801, Longitude = 67.593549 ...
# ✅ Success: Speed = 53.14 mm/yr, Azimuth = 52.5°
#
# 📍 Processing Row 10: Latitude = -7.716073, Longitude = 67.664483 ...
# ✅ Success: Speed = 53.36 mm/yr, Azimuth = 52.66°
#
# 📍 Processing Row 11: Latitude = -3.936067, Longitude = 68.099176 ...
# ✅ Success: Speed = 54.38 mm/yr, Azimuth = 53.34°
#
# 📍 Processing Row 12: Latitude = -2.770434, Longitude = 68.065208 ...
# ✅ Success: Speed = 54.64 mm/yr, Azimuth = 53.55°
#
# 📍 Processing Row 13: Latitude = -0.203897, Longitude = 66.992592 ...
# ✅ Success: Speed = 55.01 mm/yr, Azimuth = 54.17°
#
# 📍 Processing Row 14: Latitude = 0.244968, Longitude = 66.751102 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 15: Latitude = 0.623244, Longitude = 66.424292 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 16: Latitude = -2.147448, Longitude = 67.820847 ...
# ✅ Success: Speed = 54.74 mm/yr, Azimuth = 53.7°
#
# 📍 Processing Row 17: Latitude = 1.300414, Longitude = 66.306630 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 18: Latitude = 3.067083, Longitude = 65.316047 ...
# ✅ Success: Speed = 54.1 mm/yr, Azimuth = 54.03°
#
# 📍 Processing Row 19: Latitude = 10.486187, Longitude = 58.227629 ...
# ✅ Success: Speed = 50.21 mm/yr, Azimuth = 53.77°
#
# 📍 Processing Row 20: Latitude = 7.218052, Longitude = 57.561278 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 21: Latitude = -0.765224, Longitude = 67.878271 ...
# ✅ Success: Speed = 55.03 mm/yr, Azimuth = 53.91°
#
# 📍 Processing Row 22: Latitude = -0.328149, Longitude = 67.471856 ...
# ✅ Success: Speed = 55.06 mm/yr, Azimuth = 54.05°
#
# 📍 Processing Row 23: Latitude = -4.530560, Longitude = 68.268129 ...
# ✅ Success: Speed = 54.28 mm/yr, Azimuth = 53.2°
#
# 📍 Processing Row 24: Latitude = 4.584841, Longitude = 61.378014 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 25: Latitude = 6.426316, Longitude = 65.009387 ...
# ✅ Success: Speed = 53.16 mm/yr, Azimuth = 53.4°
#
# 📍 Processing Row 26: Latitude = 8.557366, Longitude = 56.879818 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 27: Latitude = 6.810187, Longitude = 58.204551 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 28: Latitude = 12.503239, Longitude = 58.058783 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 29: Latitude = -14.765798, Longitude = 66.482911 ...
# ✅ Success: Speed = 50.91 mm/yr, Azimuth = 50.95°
#
# 📍 Processing Row 30: Latitude = -12.629256, Longitude = 66.302281 ...
# ✅ Success: Speed = 51.58 mm/yr, Azimuth = 51.61°
#
# 📍 Processing Row 31: Latitude = -5.519256, Longitude = 68.103068 ...
# ✅ Success: Speed = 54.01 mm/yr, Azimuth = 53.04°
#
# 📍 Processing Row 32: Latitude = 6.692063, Longitude = 59.001750 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 33: Latitude = 3.389044, Longitude = 64.532749 ...
# ✅ Success: Speed = 53.88 mm/yr, Azimuth = 54.13°
#
# 📍 Processing Row 34: Latitude = -19.986364, Longitude = 67.311287 ...
# ✅ Success: Speed = 49.28 mm/yr, Azimuth = 49.09°
#
# 📍 Processing Row 35: Latitude = -19.593706, Longitude = 68.974705 ...
# ✅ Success: Speed = 49.92 mm/yr, Azimuth = 49.14°
#
# 📍 Processing Row 36: Latitude = -19.841264, Longitude = 66.581051 ...
# ✅ Success: Speed = 49.11 mm/yr, Azimuth = 49.2°
#
# 📍 Processing Row 37: Latitude = -6.974601, Longitude = 67.889976 ...
# ✅ Success: Speed = 53.6 mm/yr, Azimuth = 52.78°
#
# 📍 Processing Row 38: Latitude = 6.408733, Longitude = 59.566745 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 39: Latitude = -4.661969, Longitude = 68.437534 ...
# ✅ Success: Speed = 54.27 mm/yr, Azimuth = 53.15°
#
# 📍 Processing Row 40: Latitude = -1.686748, Longitude = 63.386541 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 41: Latitude = 3.883834, Longitude = 58.931392 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 42: Latitude = 3.701175, Longitude = 63.529642 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 43: Latitude = 5.118827, Longitude = 64.042622 ...
# ✅ Success: Speed = 53.33 mm/yr, Azimuth = 53.88°
#
# 📍 Processing Row 44: Latitude = 3.027941, Longitude = 59.791328 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 45: Latitude = 6.479920, Longitude = 63.570855 ...
# ✅ Success: Speed = 52.84 mm/yr, Azimuth = 53.67°
#
# 📍 Processing Row 46: Latitude = 7.135647, Longitude = 60.990057 ...
# ✅ Success: Speed = 52.07 mm/yr, Azimuth = 54.07°
#
# 📍 Processing Row 47: Latitude = 1.561634, Longitude = 60.668233 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 48: Latitude = 5.487117, Longitude = 61.552377 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 49: Latitude = 7.115112, Longitude = 62.228130 ...
# ✅ Success: Speed = 52.36 mm/yr, Azimuth = 53.8°
#
# 📍 Processing Row 50: Latitude = 6.160550, Longitude = 60.811608 ...
# ✅ Success: Speed = 0.0 mm/yr, Azimuth = 0.0°
#
# 📍 Processing Row 51: Latitude = -10.458267, Longitude = 66.579716 ...
# ✅ Success: Speed = 52.33 mm/yr, Azimuth = 52.16°
#
# 📍 Processing Row 52: Latitude = 22.748769, Longitude = 81.532035 ...
# ✅ Success: Speed = 52.24 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 53: Latitude = 22.927318, Longitude = 81.196074 ...
# ✅ Success: Speed = 52.11 mm/yr, Azimuth = 48.3°
#
# 📍 Processing Row 54: Latitude = 22.951881, Longitude = 81.028953 ...
# ✅ Success: Speed = 52.06 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 55: Latitude = 22.975714, Longitude = 80.898640 ...
# ✅ Success: Speed = 52.02 mm/yr, Azimuth = 48.26°
#
# 📍 Processing Row 56: Latitude = 23.023753, Longitude = 80.812393 ...
# ✅ Success: Speed = 51.99 mm/yr, Azimuth = 48.24°
#
# 📍 Processing Row 57: Latitude = 23.009489, Longitude = 80.786364 ...
# ✅ Success: Speed = 51.99 mm/yr, Azimuth = 48.24°
#
# 📍 Processing Row 58: Latitude = 22.777459, Longitude = 80.499541 ...
# ✅ Success: Speed = 51.99 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 59: Latitude = 22.756933, Longitude = 80.284745 ...
# ✅ Success: Speed = 51.94 mm/yr, Azimuth = 48.27°
#
# 📍 Processing Row 60: Latitude = 23.057439, Longitude = 79.108583 ...
# ✅ Success: Speed = 51.55 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 61: Latitude = 22.843832, Longitude = 77.896884 ...
# ✅ Success: Speed = 51.3 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 62: Latitude = 22.035968, Longitude = 74.460988 ...
# ✅ Success: Speed = 50.64 mm/yr, Azimuth = 48.2°
#
# 📍 Processing Row 63: Latitude = 22.038945, Longitude = 74.547350 ...
# ✅ Success: Speed = 50.66 mm/yr, Azimuth = 48.21°
#
# 📍 Processing Row 64: Latitude = 21.903460, Longitude = 74.017226 ...
# ✅ Success: Speed = 50.56 mm/yr, Azimuth = 48.24°
#
# 📍 Processing Row 65: Latitude = 22.701326, Longitude = 81.713384 ...
# ✅ Success: Speed = 52.3 mm/yr, Azimuth = 48.41°
#
# 📍 Processing Row 66: Latitude = 22.737936, Longitude = 81.702069 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 67: Latitude = 22.572741, Longitude = 80.433660 ...
# ✅ Success: Speed = 52.03 mm/yr, Azimuth = 48.34°
#
# 📍 Processing Row 68: Latitude = 22.574136, Longitude = 80.413584 ...
# ✅ Success: Speed = 52.02 mm/yr, Azimuth = 48.34°
#
# 📍 Processing Row 69: Latitude = 22.576787, Longitude = 80.364302 ...
# ✅ Success: Speed = 52.01 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 70: Latitude = 22.026916, Longitude = 80.921055 ...
# ✅ Success: Speed = 52.31 mm/yr, Azimuth = 48.53°
#
# 📍 Processing Row 71: Latitude = 22.018212, Longitude = 80.924528 ...
# ✅ Success: Speed = 52.31 mm/yr, Azimuth = 48.54°
#
# 📍 Processing Row 72: Latitude = 22.016370, Longitude = 80.923199 ...
# ✅ Success: Speed = 52.31 mm/yr, Azimuth = 48.54°
#
# 📍 Processing Row 73: Latitude = 22.295965, Longitude = 80.467131 ...
# ✅ Success: Speed = 52.12 mm/yr, Azimuth = 48.42°
#
# 📍 Processing Row 74: Latitude = 22.038383, Longitude = 80.742747 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.52°
#
# 📍 Processing Row 75: Latitude = 22.001228, Longitude = 80.803656 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.53°
#
# 📍 Processing Row 76: Latitude = 21.998195, Longitude = 80.806192 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.53°
#
# 📍 Processing Row 77: Latitude = 22.785965, Longitude = 81.657886 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 78: Latitude = 22.780847, Longitude = 81.632334 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 79: Latitude = 22.756340, Longitude = 81.590960 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 80: Latitude = 22.783092, Longitude = 81.449293 ...
# ✅ Success: Speed = 52.21 mm/yr, Azimuth = 48.36°
#
# 📍 Processing Row 81: Latitude = 23.138811, Longitude = 79.543106 ...
# ✅ Success: Speed = 51.64 mm/yr, Azimuth = 48.1°
#
# 📍 Processing Row 82: Latitude = 22.798984, Longitude = 77.765720 ...
# ✅ Success: Speed = 51.28 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 83: Latitude = 21.904277, Longitude = 73.293858 ...
# ✅ Success: Speed = 50.36 mm/yr, Azimuth = 48.23°
#
# 📍 Processing Row 84: Latitude = 22.787102, Longitude = 81.646148 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 85: Latitude = 22.746620, Longitude = 81.583582 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.39°
#
# 📍 Processing Row 86: Latitude = 22.717180, Longitude = 81.603804 ...
# ✅ Success: Speed = 52.27 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 87: Latitude = 22.710325, Longitude = 81.605394 ...
# ✅ Success: Speed = 52.27 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 88: Latitude = 22.858083, Longitude = 81.358882 ...
# ✅ Success: Speed = 52.17 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 89: Latitude = 22.861882, Longitude = 81.365848 ...
# ✅ Success: Speed = 52.17 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 90: Latitude = 22.892294, Longitude = 81.386456 ...
# ✅ Success: Speed = 52.17 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 91: Latitude = 22.893303, Longitude = 81.389535 ...
# ✅ Success: Speed = 52.17 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 92: Latitude = 22.891784, Longitude = 81.390600 ...
# ✅ Success: Speed = 52.17 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 93: Latitude = 22.860804, Longitude = 81.363606 ...
# ✅ Success: Speed = 52.17 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 94: Latitude = 22.885936, Longitude = 81.409874 ...
# ✅ Success: Speed = 52.17 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 95: Latitude = 22.893467, Longitude = 81.385559 ...
# ✅ Success: Speed = 52.17 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 96: Latitude = 22.779509, Longitude = 81.627847 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 97: Latitude = 22.736981, Longitude = 81.591787 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.39°
#
# 📍 Processing Row 98: Latitude = 22.801958, Longitude = 78.081776 ...
# ✅ Success: Speed = 51.37 mm/yr, Azimuth = 48.1°
#
# 📍 Processing Row 99: Latitude = 22.849269, Longitude = 80.484138 ...
# ✅ Success: Speed = 51.96 mm/yr, Azimuth = 48.26°
#
# 📍 Processing Row 100: Latitude = 22.950671, Longitude = 80.513112 ...
# ✅ Success: Speed = 51.94 mm/yr, Azimuth = 48.24°
#
# 📍 Processing Row 101: Latitude = 22.778883, Longitude = 81.611241 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 102: Latitude = 22.797186, Longitude = 81.634636 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 103: Latitude = 22.725723, Longitude = 81.698708 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 104: Latitude = 22.779653, Longitude = 81.690764 ...
# ✅ Success: Speed = 52.27 mm/yr, Azimuth = 48.39°
#
# 📍 Processing Row 105: Latitude = 22.764811, Longitude = 81.606067 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 106: Latitude = 22.756481, Longitude = 81.565644 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 107: Latitude = 22.751761, Longitude = 81.543331 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 108: Latitude = 22.723591, Longitude = 81.458351 ...
# ✅ Success: Speed = 52.23 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 109: Latitude = 22.869541, Longitude = 81.309385 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 110: Latitude = 22.826237, Longitude = 81.328308 ...
# ✅ Success: Speed = 52.17 mm/yr, Azimuth = 48.34°
#
# 📍 Processing Row 111: Latitude = 22.825649, Longitude = 81.328256 ...
# ✅ Success: Speed = 52.17 mm/yr, Azimuth = 48.34°
#
# 📍 Processing Row 112: Latitude = 22.783298, Longitude = 81.322439 ...
# ✅ Success: Speed = 52.18 mm/yr, Azimuth = 48.35°
#
# 📍 Processing Row 113: Latitude = 22.772191, Longitude = 81.327409 ...
# ✅ Success: Speed = 52.19 mm/yr, Azimuth = 48.36°
#
# 📍 Processing Row 114: Latitude = 22.662981, Longitude = 81.344341 ...
# ✅ Success: Speed = 52.22 mm/yr, Azimuth = 48.39°
#
# 📍 Processing Row 115: Latitude = 22.605719, Longitude = 81.396876 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.41°
#
# 📍 Processing Row 116: Latitude = 22.775473, Longitude = 80.668882 ...
# ✅ Success: Speed = 52.03 mm/yr, Azimuth = 48.3°
#
# 📍 Processing Row 117: Latitude = 22.329075, Longitude = 76.437888 ...
# ✅ Success: Speed = 51.08 mm/yr, Azimuth = 48.17°
#
# 📍 Processing Row 118: Latitude = 22.867359, Longitude = 77.858772 ...
# ✅ Success: Speed = 51.29 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 119: Latitude = 22.824667, Longitude = 77.976668 ...
# ✅ Success: Speed = 51.33 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 120: Latitude = 22.881221, Longitude = 78.226302 ...
# ✅ Success: Speed = 51.38 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 121: Latitude = 23.127418, Longitude = 79.797880 ...
# ✅ Success: Speed = 51.7 mm/yr, Azimuth = 48.12°
#
# 📍 Processing Row 122: Latitude = 23.124897, Longitude = 79.808906 ...
# ✅ Success: Speed = 51.71 mm/yr, Azimuth = 48.13°
#
# 📍 Processing Row 123: Latitude = 23.086108, Longitude = 79.952612 ...
# ✅ Success: Speed = 51.76 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 124: Latitude = 22.274173, Longitude = 76.202081 ...
# ✅ Success: Speed = 51.04 mm/yr, Azimuth = 48.18°
#
# 📍 Processing Row 125: Latitude = 22.762852, Longitude = 81.581977 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 126: Latitude = 22.763532, Longitude = 81.582092 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 127: Latitude = 22.777588, Longitude = 81.597875 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 128: Latitude = 22.725995, Longitude = 81.340062 ...
# ✅ Success: Speed = 52.2 mm/yr, Azimuth = 48.37°
#
# 📍 Processing Row 129: Latitude = 22.714390, Longitude = 81.353501 ...
# ✅ Success: Speed = 52.21 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 130: Latitude = 22.624629, Longitude = 81.355211 ...
# ✅ Success: Speed = 52.24 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 131: Latitude = 22.915710, Longitude = 80.909084 ...
# ✅ Success: Speed = 52.04 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 132: Latitude = 23.120395, Longitude = 79.485716 ...
# ✅ Success: Speed = 51.63 mm/yr, Azimuth = 48.1°
#
# 📍 Processing Row 133: Latitude = 22.621352, Longitude = 80.717512 ...
# ✅ Success: Speed = 52.08 mm/yr, Azimuth = 48.35°
#
# 📍 Processing Row 134: Latitude = 22.200799, Longitude = 80.776932 ...
# ✅ Success: Speed = 52.22 mm/yr, Azimuth = 48.47°
#
# 📍 Processing Row 135: Latitude = 22.170441, Longitude = 80.775692 ...
# ✅ Success: Speed = 52.23 mm/yr, Azimuth = 48.48°
#
# 📍 Processing Row 136: Latitude = 22.779497, Longitude = 78.634974 ...
# ✅ Success: Speed = 51.52 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 137: Latitude = 22.744492, Longitude = 78.688077 ...
# ✅ Success: Speed = 51.54 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 138: Latitude = 22.652282, Longitude = 78.702701 ...
# ✅ Success: Speed = 51.57 mm/yr, Azimuth = 48.19°
#
# 📍 Processing Row 139: Latitude = 22.884481, Longitude = 78.875625 ...
# ✅ Success: Speed = 51.54 mm/yr, Azimuth = 48.13°
#
# 📍 Processing Row 140: Latitude = 22.881319, Longitude = 78.879271 ...
# ✅ Success: Speed = 51.55 mm/yr, Azimuth = 48.13°
#
# 📍 Processing Row 141: Latitude = 22.831100, Longitude = 78.925036 ...
# ✅ Success: Speed = 51.57 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 142: Latitude = 22.690195, Longitude = 79.175766 ...
# ✅ Success: Speed = 51.68 mm/yr, Azimuth = 48.21°
#
# 📍 Processing Row 143: Latitude = 22.690096, Longitude = 79.187911 ...
# ✅ Success: Speed = 51.68 mm/yr, Azimuth = 48.21°
#
# 📍 Processing Row 144: Latitude = 22.687406, Longitude = 79.196414 ...
# ✅ Success: Speed = 51.69 mm/yr, Azimuth = 48.21°
#
# 📍 Processing Row 145: Latitude = 22.636625, Longitude = 79.208402 ...
# ✅ Success: Speed = 51.71 mm/yr, Azimuth = 48.23°
#
# 📍 Processing Row 146: Latitude = 22.515461, Longitude = 79.212509 ...
# ✅ Success: Speed = 51.74 mm/yr, Azimuth = 48.27°
#
# 📍 Processing Row 147: Latitude = 22.497994, Longitude = 79.224436 ...
# ✅ Success: Speed = 51.75 mm/yr, Azimuth = 48.27°
#
# 📍 Processing Row 148: Latitude = 22.703894, Longitude = 78.688228 ...
# ✅ Success: Speed = 51.55 mm/yr, Azimuth = 48.17°
#
# 📍 Processing Row 149: Latitude = 22.194755, Longitude = 80.777171 ...
# ✅ Success: Speed = 52.22 mm/yr, Azimuth = 48.47°
#
# 📍 Processing Row 150: Latitude = 22.037807, Longitude = 80.747255 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.52°
#
# 📍 Processing Row 151: Latitude = 22.165913, Longitude = 80.615765 ...
# ✅ Success: Speed = 52.19 mm/yr, Azimuth = 48.47°
#
# 📍 Processing Row 152: Latitude = 22.173062, Longitude = 80.558875 ...
# ✅ Success: Speed = 52.18 mm/yr, Azimuth = 48.46°
#
# 📍 Processing Row 153: Latitude = 22.191832, Longitude = 80.522428 ...
# ✅ Success: Speed = 52.16 mm/yr, Azimuth = 48.46°
#
# 📍 Processing Row 154: Latitude = 22.753096, Longitude = 81.580404 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 155: Latitude = 22.773098, Longitude = 81.623210 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 156: Latitude = 22.748018, Longitude = 81.600155 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.39°
#
# 📍 Processing Row 157: Latitude = 22.740157, Longitude = 81.587503 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.39°
#
# 📍 Processing Row 158: Latitude = 23.037128, Longitude = 80.864187 ...
# ✅ Success: Speed = 52.0 mm/yr, Azimuth = 48.24°
#
# 📍 Processing Row 159: Latitude = 22.661931, Longitude = 81.464999 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 160: Latitude = 22.639806, Longitude = 81.452475 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 161: Latitude = 22.628043, Longitude = 81.454224 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.41°
#
# 📍 Processing Row 162: Latitude = 22.597460, Longitude = 81.491479 ...
# ✅ Success: Speed = 52.28 mm/yr, Azimuth = 48.42°
#
# 📍 Processing Row 163: Latitude = 22.556857, Longitude = 81.511216 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.43°
#
# 📍 Processing Row 164: Latitude = 22.540774, Longitude = 81.496561 ...
# ✅ Success: Speed = 52.3 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 165: Latitude = 22.541296, Longitude = 81.495628 ...
# ✅ Success: Speed = 52.3 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 166: Latitude = 22.494891, Longitude = 81.421321 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 167: Latitude = 22.489462, Longitude = 81.419018 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 168: Latitude = 22.479886, Longitude = 81.416041 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.45°
#
# 📍 Processing Row 169: Latitude = 22.479964, Longitude = 81.416536 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.45°
#
# 📍 Processing Row 170: Latitude = 22.495881, Longitude = 81.420503 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 171: Latitude = 22.500177, Longitude = 81.420584 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 172: Latitude = 22.499597, Longitude = 81.420881 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 173: Latitude = 22.510830, Longitude = 81.421071 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 174: Latitude = 22.525676, Longitude = 81.442905 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 175: Latitude = 22.525032, Longitude = 81.443521 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 176: Latitude = 22.529396, Longitude = 81.453668 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 177: Latitude = 22.530182, Longitude = 81.467304 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 178: Latitude = 22.533450, Longitude = 81.475333 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 179: Latitude = 22.537704, Longitude = 81.489268 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 180: Latitude = 22.539993, Longitude = 81.499298 ...
# ✅ Success: Speed = 52.3 mm/yr, Azimuth = 48.44°
#
# 📍 Processing Row 181: Latitude = 22.579546, Longitude = 81.494863 ...
# ✅ Success: Speed = 52.28 mm/yr, Azimuth = 48.43°
#
# 📍 Processing Row 182: Latitude = 22.582042, Longitude = 81.492837 ...
# ✅ Success: Speed = 52.28 mm/yr, Azimuth = 48.42°
#
# 📍 Processing Row 183: Latitude = 22.607923, Longitude = 81.482204 ...
# ✅ Success: Speed = 52.27 mm/yr, Azimuth = 48.42°
#
# 📍 Processing Row 184: Latitude = 22.607283, Longitude = 81.476514 ...
# ✅ Success: Speed = 52.27 mm/yr, Azimuth = 48.42°
#
# 📍 Processing Row 185: Latitude = 22.659311, Longitude = 81.461925 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 186: Latitude = 22.675818, Longitude = 81.455732 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 187: Latitude = 22.676340, Longitude = 81.452116 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.39°
#
# 📍 Processing Row 188: Latitude = 22.741342, Longitude = 81.605603 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.39°
#
# 📍 Processing Row 189: Latitude = 22.741884, Longitude = 81.602431 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.39°
#
# 📍 Processing Row 190: Latitude = 22.741567, Longitude = 81.609904 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.39°
#
# 📍 Processing Row 191: Latitude = 22.727444, Longitude = 81.640652 ...
# ✅ Success: Speed = 52.28 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 192: Latitude = 22.720807, Longitude = 81.643614 ...
# ✅ Success: Speed = 52.28 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 193: Latitude = 22.707356, Longitude = 81.652837 ...
# ✅ Success: Speed = 52.28 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 194: Latitude = 22.704139, Longitude = 81.653018 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 195: Latitude = 22.697608, Longitude = 81.655664 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.41°
#
# 📍 Processing Row 196: Latitude = 22.733069, Longitude = 81.702445 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 197: Latitude = 22.763691, Longitude = 81.508643 ...
# ✅ Success: Speed = 52.23 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 198: Latitude = 23.060739, Longitude = 80.884741 ...
# ✅ Success: Speed = 51.99 mm/yr, Azimuth = 48.23°
#
# 📍 Processing Row 199: Latitude = 23.055255, Longitude = 80.929447 ...
# ✅ Success: Speed = 52.01 mm/yr, Azimuth = 48.24°
#
# 📍 Processing Row 200: Latitude = 23.053341, Longitude = 80.954859 ...
# ✅ Success: Speed = 52.01 mm/yr, Azimuth = 48.24°
#
# 📍 Processing Row 201: Latitude = 23.099235, Longitude = 81.012714 ...
# ✅ Success: Speed = 52.01 mm/yr, Azimuth = 48.23°
#
# 📍 Processing Row 202: Latitude = 23.101728, Longitude = 81.024546 ...
# ✅ Success: Speed = 52.02 mm/yr, Azimuth = 48.23°
#
# 📍 Processing Row 203: Latitude = 23.040693, Longitude = 80.967934 ...
# ✅ Success: Speed = 52.02 mm/yr, Azimuth = 48.25°
#
# 📍 Processing Row 204: Latitude = 23.040483, Longitude = 80.972521 ...
# ✅ Success: Speed = 52.02 mm/yr, Azimuth = 48.25°
#
# 📍 Processing Row 205: Latitude = 23.027421, Longitude = 81.016569 ...
# ✅ Success: Speed = 52.04 mm/yr, Azimuth = 48.26°
#
# 📍 Processing Row 206: Latitude = 23.044460, Longitude = 81.032184 ...
# ✅ Success: Speed = 52.04 mm/yr, Azimuth = 48.25°
#
# 📍 Processing Row 207: Latitude = 23.025791, Longitude = 81.015189 ...
# ✅ Success: Speed = 52.04 mm/yr, Azimuth = 48.26°
#
# 📍 Processing Row 208: Latitude = 23.039122, Longitude = 80.977565 ...
# ✅ Success: Speed = 52.02 mm/yr, Azimuth = 48.25°
#
# 📍 Processing Row 209: Latitude = 23.005595, Longitude = 80.708131 ...
# ✅ Success: Speed = 51.97 mm/yr, Azimuth = 48.24°
#
# 📍 Processing Row 210: Latitude = 22.671791, Longitude = 81.457340 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 211: Latitude = 22.642922, Longitude = 81.452789 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 212: Latitude = 22.618058, Longitude = 81.465472 ...
# ✅ Success: Speed = 52.27 mm/yr, Azimuth = 48.41°
#
# 📍 Processing Row 213: Latitude = 22.968994, Longitude = 81.047656 ...
# ✅ Success: Speed = 52.06 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 214: Latitude = 22.900044, Longitude = 80.528254 ...
# ✅ Success: Speed = 51.96 mm/yr, Azimuth = 48.25°
#
# 📍 Processing Row 215: Latitude = 22.543196, Longitude = 80.359997 ...
# ✅ Success: Speed = 52.02 mm/yr, Azimuth = 48.34°
#
# 📍 Processing Row 216: Latitude = 22.201260, Longitude = 80.484137 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.45°
#
# 📍 Processing Row 217: Latitude = 21.895872, Longitude = 73.482852 ...
# ✅ Success: Speed = 50.41 mm/yr, Azimuth = 48.24°
#
# 📍 Processing Row 218: Latitude = 21.859334, Longitude = 73.477127 ...
# ✅ Success: Speed = 50.42 mm/yr, Azimuth = 48.25°
#
# 📍 Processing Row 219: Latitude = 22.110825, Longitude = 74.463992 ...
# ✅ Success: Speed = 50.61 mm/yr, Azimuth = 48.18°
#
# 📍 Processing Row 220: Latitude = 22.225124, Longitude = 74.523334 ...
# ✅ Success: Speed = 50.59 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 221: Latitude = 22.230575, Longitude = 74.535590 ...
# ✅ Success: Speed = 50.59 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 222: Latitude = 22.243773, Longitude = 74.562058 ...
# ✅ Success: Speed = 50.6 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 223: Latitude = 22.244443, Longitude = 74.577967 ...
# ✅ Success: Speed = 50.6 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 224: Latitude = 22.259760, Longitude = 74.588446 ...
# ✅ Success: Speed = 50.6 mm/yr, Azimuth = 48.13°
#
# 📍 Processing Row 225: Latitude = 22.266572, Longitude = 74.919601 ...
# ✅ Success: Speed = 50.69 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 226: Latitude = 23.086541, Longitude = 79.974365 ...
# ✅ Success: Speed = 51.76 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 227: Latitude = 23.100342, Longitude = 79.978589 ...
# ✅ Success: Speed = 51.76 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 228: Latitude = 23.171381, Longitude = 80.122753 ...
# ✅ Success: Speed = 51.77 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 229: Latitude = 23.162338, Longitude = 80.132979 ...
# ✅ Success: Speed = 51.78 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 230: Latitude = 23.122665, Longitude = 80.174854 ...
# ✅ Success: Speed = 51.8 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 231: Latitude = 23.141442, Longitude = 80.240395 ...
# ✅ Success: Speed = 51.81 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 232: Latitude = 23.143641, Longitude = 80.278100 ...
# ✅ Success: Speed = 51.82 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 233: Latitude = 23.148729, Longitude = 80.245793 ...
# ✅ Success: Speed = 51.81 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 234: Latitude = 23.070142, Longitude = 80.313761 ...
# ✅ Success: Speed = 51.85 mm/yr, Azimuth = 48.18°
#
# 📍 Processing Row 235: Latitude = 23.071582, Longitude = 80.346942 ...
# ✅ Success: Speed = 51.86 mm/yr, Azimuth = 48.19°
#
# 📍 Processing Row 236: Latitude = 23.024488, Longitude = 80.414859 ...
# ✅ Success: Speed = 51.89 mm/yr, Azimuth = 48.21°
#
# 📍 Processing Row 237: Latitude = 23.029122, Longitude = 80.416989 ...
# ✅ Success: Speed = 51.89 mm/yr, Azimuth = 48.2°
#
# 📍 Processing Row 238: Latitude = 23.018966, Longitude = 80.432386 ...
# ✅ Success: Speed = 51.9 mm/yr, Azimuth = 48.21°
#
# 📍 Processing Row 239: Latitude = 23.018553, Longitude = 80.443503 ...
# ✅ Success: Speed = 51.9 mm/yr, Azimuth = 48.21°
#
# 📍 Processing Row 240: Latitude = 23.041443, Longitude = 80.393265 ...
# ✅ Success: Speed = 51.88 mm/yr, Azimuth = 48.2°
#
# 📍 Processing Row 241: Latitude = 23.056141, Longitude = 80.390553 ...
# ✅ Success: Speed = 51.87 mm/yr, Azimuth = 48.19°
#
# 📍 Processing Row 242: Latitude = 23.061978, Longitude = 80.386249 ...
# ✅ Success: Speed = 51.87 mm/yr, Azimuth = 48.19°
#
# 📍 Processing Row 243: Latitude = 22.854253, Longitude = 81.721096 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.37°
#
# 📍 Processing Row 244: Latitude = 22.846994, Longitude = 81.734864 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.37°
#
# 📍 Processing Row 245: Latitude = 22.847309, Longitude = 81.736129 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.37°
#
# 📍 Processing Row 246: Latitude = 22.968978, Longitude = 81.497568 ...
# ✅ Success: Speed = 52.17 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 247: Latitude = 22.945165, Longitude = 81.427666 ...
# ✅ Success: Speed = 52.16 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 248: Latitude = 22.785384, Longitude = 81.637203 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 249: Latitude = 22.402465, Longitude = 81.444947 ...
# ✅ Success: Speed = 52.32 mm/yr, Azimuth = 48.47°
#
# 📍 Processing Row 250: Latitude = 22.404128, Longitude = 81.442212 ...
# ✅ Success: Speed = 52.32 mm/yr, Azimuth = 48.47°
#
# 📍 Processing Row 251: Latitude = 22.907100, Longitude = 81.175561 ...
# ✅ Success: Speed = 52.11 mm/yr, Azimuth = 48.3°
#
# 📍 Processing Row 252: Latitude = 22.784947, Longitude = 81.175727 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.34°
#
# 📍 Processing Row 253: Latitude = 22.627339, Longitude = 81.457455 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.41°
#
# 📍 Processing Row 254: Latitude = 22.928021, Longitude = 81.504366 ...
# ✅ Success: Speed = 52.18 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 255: Latitude = 22.933116, Longitude = 81.506427 ...
# ✅ Success: Speed = 52.18 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 256: Latitude = 23.802864, Longitude = 80.318090 ...
# ✅ Success: Speed = 51.63 mm/yr, Azimuth = 47.96°
#
# 📍 Processing Row 257: Latitude = 22.375714, Longitude = 81.232800 ...
# ✅ Success: Speed = 52.28 mm/yr, Azimuth = 48.46°
#
# 📍 Processing Row 258: Latitude = 23.131049, Longitude = 80.290284 ...
# ✅ Success: Speed = 51.83 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 259: Latitude = 23.130417, Longitude = 80.295575 ...
# ✅ Success: Speed = 51.83 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 260: Latitude = 23.160896, Longitude = 80.439859 ...
# ✅ Success: Speed = 51.85 mm/yr, Azimuth = 48.17°
#
# 📍 Processing Row 261: Latitude = 23.279490, Longitude = 80.513757 ...
# ✅ Success: Speed = 51.84 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 262: Latitude = 23.843049, Longitude = 80.630224 ...
# ✅ Success: Speed = 51.7 mm/yr, Azimuth = 47.98°
#
# 📍 Processing Row 263: Latitude = 23.206374, Longitude = 80.632541 ...
# ✅ Success: Speed = 51.89 mm/yr, Azimuth = 48.17°
#
# 📍 Processing Row 264: Latitude = 23.220298, Longitude = 80.608433 ...
# ✅ Success: Speed = 51.88 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 265: Latitude = 23.802594, Longitude = 80.319641 ...
# ✅ Success: Speed = 51.63 mm/yr, Azimuth = 47.96°
#
# 📍 Processing Row 266: Latitude = 23.804300, Longitude = 80.317665 ...
# ✅ Success: Speed = 51.63 mm/yr, Azimuth = 47.96°
#
# 📍 Processing Row 267: Latitude = 23.774208, Longitude = 80.259370 ...
# ✅ Success: Speed = 51.62 mm/yr, Azimuth = 47.97°
#
# 📍 Processing Row 268: Latitude = 23.151664, Longitude = 80.433026 ...
# ✅ Success: Speed = 51.86 mm/yr, Azimuth = 48.17°
#
# 📍 Processing Row 269: Latitude = 23.423553, Longitude = 79.954901 ...
# ✅ Success: Speed = 51.65 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 270: Latitude = 23.365146, Longitude = 79.881188 ...
# ✅ Success: Speed = 51.65 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 271: Latitude = 23.014714, Longitude = 78.704016 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 272: Latitude = 22.918372, Longitude = 78.336007 ...
# ✅ Success: Speed = 51.39 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 273: Latitude = 22.923578, Longitude = 78.379033 ...
# ✅ Success: Speed = 51.4 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 274: Latitude = 22.971986, Longitude = 78.507034 ...
# ✅ Success: Speed = 51.42 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 275: Latitude = 21.974734, Longitude = 80.823467 ...
# ✅ Success: Speed = 52.3 mm/yr, Azimuth = 48.54°
#
# 📍 Processing Row 276: Latitude = 21.966174, Longitude = 80.828124 ...
# ✅ Success: Speed = 52.3 mm/yr, Azimuth = 48.54°
#
# 📍 Processing Row 277: Latitude = 21.946375, Longitude = 80.840017 ...
# ✅ Success: Speed = 52.31 mm/yr, Azimuth = 48.55°
#
# 📍 Processing Row 278: Latitude = 21.947187, Longitude = 80.834747 ...
# ✅ Success: Speed = 52.31 mm/yr, Azimuth = 48.55°
#
# 📍 Processing Row 279: Latitude = 23.152934, Longitude = 80.269820 ...
# ✅ Success: Speed = 51.82 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 280: Latitude = 22.728325, Longitude = 81.594740 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.39°
#
# 📍 Processing Row 281: Latitude = 22.760789, Longitude = 81.558213 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 282: Latitude = 21.875295, Longitude = 80.844693 ...
# ✅ Success: Speed = 52.33 mm/yr, Azimuth = 48.57°
#
# 📍 Processing Row 283: Latitude = 22.527981, Longitude = 80.392940 ...
# ✅ Success: Speed = 52.03 mm/yr, Azimuth = 48.35°
#
# 📍 Processing Row 284: Latitude = 22.430904, Longitude = 79.021336 ...
# ✅ Success: Speed = 51.72 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 285: Latitude = 22.414237, Longitude = 78.959832 ...
# ✅ Success: Speed = 51.71 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 286: Latitude = 22.418459, Longitude = 78.961903 ...
# ✅ Success: Speed = 51.71 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 287: Latitude = 22.464925, Longitude = 79.078436 ...
# ✅ Success: Speed = 51.73 mm/yr, Azimuth = 48.27°
#
# 📍 Processing Row 288: Latitude = 22.425624, Longitude = 79.013534 ...
# ✅ Success: Speed = 51.72 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 289: Latitude = 22.703801, Longitude = 81.652039 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 290: Latitude = 22.686593, Longitude = 81.667513 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.41°
#
# 📍 Processing Row 291: Latitude = 22.738890, Longitude = 81.612335 ...
# ✅ Success: Speed = 52.27 mm/yr, Azimuth = 48.39°
#
# 📍 Processing Row 292: Latitude = 22.734298, Longitude = 81.631987 ...
# ✅ Success: Speed = 52.27 mm/yr, Azimuth = 48.39°
#
# 📍 Processing Row 293: Latitude = 22.753508, Longitude = 81.523197 ...
# ✅ Success: Speed = 52.24 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 294: Latitude = 23.068754, Longitude = 78.747716 ...
# ✅ Success: Speed = 51.45 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 295: Latitude = 23.247411, Longitude = 78.771919 ...
# ✅ Success: Speed = 51.4 mm/yr, Azimuth = 48.01°
#
# 📍 Processing Row 296: Latitude = 23.253104, Longitude = 78.761230 ...
# ✅ Success: Speed = 51.4 mm/yr, Azimuth = 48.01°
#
# 📍 Processing Row 297: Latitude = 23.359724, Longitude = 78.692228 ...
# ✅ Success: Speed = 51.35 mm/yr, Azimuth = 47.97°
#
# 📍 Processing Row 298: Latitude = 23.113153, Longitude = 78.797612 ...
# ✅ Success: Speed = 51.45 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 299: Latitude = 23.122473, Longitude = 78.920325 ...
# ✅ Success: Speed = 51.48 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 300: Latitude = 23.151864, Longitude = 78.957190 ...
# ✅ Success: Speed = 51.48 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 301: Latitude = 23.152219, Longitude = 78.991658 ...
# ✅ Success: Speed = 51.49 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 302: Latitude = 22.480496, Longitude = 79.237869 ...
# ✅ Success: Speed = 51.76 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 303: Latitude = 22.454256, Longitude = 79.221481 ...
# ✅ Success: Speed = 51.77 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 304: Latitude = 22.614195, Longitude = 79.184501 ...
# ✅ Success: Speed = 51.71 mm/yr, Azimuth = 48.23°
#
# 📍 Processing Row 305: Latitude = 22.859360, Longitude = 78.892515 ...
# ✅ Success: Speed = 51.56 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 306: Latitude = 22.583158, Longitude = 79.097753 ...
# ✅ Success: Speed = 51.69 mm/yr, Azimuth = 48.24°
#
# 📍 Processing Row 307: Latitude = 22.412369, Longitude = 78.947244 ...
# ✅ Success: Speed = 51.71 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 308: Latitude = 22.396391, Longitude = 78.886424 ...
# ✅ Success: Speed = 51.7 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 309: Latitude = 22.388276, Longitude = 78.884860 ...
# ✅ Success: Speed = 51.7 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 310: Latitude = 22.385233, Longitude = 78.880069 ...
# ✅ Success: Speed = 51.7 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 311: Latitude = 22.391667, Longitude = 78.886999 ...
# ✅ Success: Speed = 51.7 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 312: Latitude = 22.396137, Longitude = 78.926107 ...
# ✅ Success: Speed = 51.71 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 313: Latitude = 22.414838, Longitude = 78.933188 ...
# ✅ Success: Speed = 51.7 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 314: Latitude = 22.436922, Longitude = 78.875415 ...
# ✅ Success: Speed = 51.68 mm/yr, Azimuth = 48.27°
#
# 📍 Processing Row 315: Latitude = 22.442837, Longitude = 78.872221 ...
# ✅ Success: Speed = 51.68 mm/yr, Azimuth = 48.27°
#
# 📍 Processing Row 316: Latitude = 22.450986, Longitude = 78.885273 ...
# ✅ Success: Speed = 51.68 mm/yr, Azimuth = 48.26°
#
# 📍 Processing Row 317: Latitude = 22.481817, Longitude = 78.891698 ...
# ✅ Success: Speed = 51.67 mm/yr, Azimuth = 48.25°
#
# 📍 Processing Row 318: Latitude = 22.491405, Longitude = 78.913810 ...
# ✅ Success: Speed = 51.68 mm/yr, Azimuth = 48.25°
#
# 📍 Processing Row 319: Latitude = 22.483931, Longitude = 78.916414 ...
# ✅ Success: Speed = 51.68 mm/yr, Azimuth = 48.26°
#
# 📍 Processing Row 320: Latitude = 22.498185, Longitude = 78.926832 ...
# ✅ Success: Speed = 51.68 mm/yr, Azimuth = 48.25°
#
# 📍 Processing Row 321: Latitude = 22.619948, Longitude = 78.847289 ...
# ✅ Success: Speed = 51.62 mm/yr, Azimuth = 48.21°
#
# 📍 Processing Row 322: Latitude = 23.180074, Longitude = 78.452163 ...
# ✅ Success: Speed = 51.34 mm/yr, Azimuth = 48.01°
#
# 📍 Processing Row 323: Latitude = 22.752761, Longitude = 81.530869 ...
# ✅ Success: Speed = 52.24 mm/yr, Azimuth = 48.38°
#
# 📍 Processing Row 324: Latitude = 22.661924, Longitude = 81.465046 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 325: Latitude = 22.639854, Longitude = 81.452520 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 326: Latitude = 22.628081, Longitude = 81.454211 ...
# ✅ Success: Speed = 52.26 mm/yr, Azimuth = 48.41°
#
# 📍 Processing Row 327: Latitude = 22.604433, Longitude = 81.484670 ...
# ✅ Success: Speed = 52.27 mm/yr, Azimuth = 48.42°
#
# 📍 Processing Row 328: Latitude = 22.564010, Longitude = 81.507104 ...
# ✅ Success: Speed = 52.29 mm/yr, Azimuth = 48.43°
#
# 📍 Processing Row 329: Latitude = 22.689629, Longitude = 81.460012 ...
# ✅ Success: Speed = 52.24 mm/yr, Azimuth = 48.39°
#
# 📍 Processing Row 330: Latitude = 22.678844, Longitude = 81.465568 ...
# ✅ Success: Speed = 52.25 mm/yr, Azimuth = 48.4°
#
# 📍 Processing Row 331: Latitude = 22.700174, Longitude = 81.709704 ...
# ✅ Success: Speed = 52.3 mm/yr, Azimuth = 48.41°
#
# 📍 Processing Row 332: Latitude = 21.769716, Longitude = 73.188333 ...
# ✅ Success: Speed = 50.37 mm/yr, Azimuth = 48.28°
#
# 📍 Processing Row 333: Latitude = 21.895918, Longitude = 73.436951 ...
# ✅ Success: Speed = 50.4 mm/yr, Azimuth = 48.24°
#
# 📍 Processing Row 334: Latitude = 21.904189, Longitude = 73.435812 ...
# ✅ Success: Speed = 50.4 mm/yr, Azimuth = 48.23°
#
# 📍 Processing Row 335: Latitude = 21.854926, Longitude = 73.455838 ...
# ✅ Success: Speed = 50.42 mm/yr, Azimuth = 48.25°
#
# 📍 Processing Row 336: Latitude = 21.872625, Longitude = 73.445786 ...
# ✅ Success: Speed = 50.41 mm/yr, Azimuth = 48.24°
#
# 📍 Processing Row 337: Latitude = 22.056182, Longitude = 73.480300 ...
# ✅ Success: Speed = 50.36 mm/yr, Azimuth = 48.18°
#
# 📍 Processing Row 338: Latitude = 22.141327, Longitude = 73.877295 ...
# ✅ Success: Speed = 50.44 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 339: Latitude = 22.195480, Longitude = 74.060563 ...
# ✅ Success: Speed = 50.47 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 340: Latitude = 22.175160, Longitude = 74.177783 ...
# ✅ Success: Speed = 50.51 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 341: Latitude = 22.181158, Longitude = 74.047740 ...
# ✅ Success: Speed = 50.47 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 342: Latitude = 22.172223, Longitude = 74.056631 ...
# ✅ Success: Speed = 50.48 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 343: Latitude = 22.173478, Longitude = 74.070582 ...
# ✅ Success: Speed = 50.48 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 344: Latitude = 22.166080, Longitude = 74.079486 ...
# ✅ Success: Speed = 50.49 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 345: Latitude = 22.152728, Longitude = 74.124796 ...
# ✅ Success: Speed = 50.51 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 346: Latitude = 22.141947, Longitude = 74.143638 ...
# ✅ Success: Speed = 50.51 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 347: Latitude = 22.140607, Longitude = 74.148964 ...
# ✅ Success: Speed = 50.52 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 348: Latitude = 22.054699, Longitude = 74.093946 ...
# ✅ Success: Speed = 50.53 mm/yr, Azimuth = 48.19°
#
# 📍 Processing Row 349: Latitude = 22.953661, Longitude = 81.181622 ...
# ✅ Success: Speed = 52.1 mm/yr, Azimuth = 48.29°
#
# 📍 Processing Row 350: Latitude = 22.960063, Longitude = 81.182184 ...
# ✅ Success: Speed = 52.1 mm/yr, Azimuth = 48.29°
#
# 📍 Processing Row 351: Latitude = 22.958073, Longitude = 81.181646 ...
# ✅ Success: Speed = 52.1 mm/yr, Azimuth = 48.29°
#
# 📍 Processing Row 352: Latitude = 22.917621, Longitude = 81.220043 ...
# ✅ Success: Speed = 52.12 mm/yr, Azimuth = 48.31°
#
# 📍 Processing Row 353: Latitude = 22.925724, Longitude = 81.228957 ...
# ✅ Success: Speed = 52.12 mm/yr, Azimuth = 48.3°
#
# 📍 Processing Row 354: Latitude = 22.929168, Longitude = 81.229556 ...
# ✅ Success: Speed = 52.12 mm/yr, Azimuth = 48.3°
#
# 📍 Processing Row 355: Latitude = 22.933212, Longitude = 81.228820 ...
# ✅ Success: Speed = 52.12 mm/yr, Azimuth = 48.3°
#
# 📍 Processing Row 356: Latitude = 22.947417, Longitude = 81.192863 ...
# ✅ Success: Speed = 52.1 mm/yr, Azimuth = 48.29°
#
# 📍 Processing Row 357: Latitude = 22.956716, Longitude = 81.197753 ...
# ✅ Success: Speed = 52.1 mm/yr, Azimuth = 48.29°
#
# 📍 Processing Row 358: Latitude = 22.949504, Longitude = 81.210221 ...
# ✅ Success: Speed = 52.11 mm/yr, Azimuth = 48.3°
#
# 📍 Processing Row 359: Latitude = 22.951961, Longitude = 81.211672 ...
# ✅ Success: Speed = 52.11 mm/yr, Azimuth = 48.29°
#
# 📍 Processing Row 360: Latitude = 22.955078, Longitude = 81.217524 ...
# ✅ Success: Speed = 52.11 mm/yr, Azimuth = 48.29°
#
# 📍 Processing Row 361: Latitude = 22.955903, Longitude = 81.219885 ...
# ✅ Success: Speed = 52.11 mm/yr, Azimuth = 48.29°
#
# 📍 Processing Row 362: Latitude = 22.962608, Longitude = 81.225502 ...
# ✅ Success: Speed = 52.11 mm/yr, Azimuth = 48.29°
#
# 📍 Processing Row 363: Latitude = 22.954473, Longitude = 81.216293 ...
# ✅ Success: Speed = 52.11 mm/yr, Azimuth = 48.29°
#
# 📍 Processing Row 364: Latitude = 22.890885, Longitude = 81.270994 ...
# ✅ Success: Speed = 52.14 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 365: Latitude = 22.892596, Longitude = 81.273004 ...
# ✅ Success: Speed = 52.14 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 366: Latitude = 22.910463, Longitude = 81.284914 ...
# ✅ Success: Speed = 52.14 mm/yr, Azimuth = 48.31°
#
# 📍 Processing Row 367: Latitude = 22.916711, Longitude = 81.285885 ...
# ✅ Success: Speed = 52.14 mm/yr, Azimuth = 48.31°
#
# 📍 Processing Row 368: Latitude = 22.913761, Longitude = 81.282654 ...
# ✅ Success: Speed = 52.14 mm/yr, Azimuth = 48.31°
#
# 📍 Processing Row 369: Latitude = 22.940609, Longitude = 81.294520 ...
# ✅ Success: Speed = 52.13 mm/yr, Azimuth = 48.31°
#
# 📍 Processing Row 370: Latitude = 22.946511, Longitude = 81.295636 ...
# ✅ Success: Speed = 52.13 mm/yr, Azimuth = 48.3°
#
# 📍 Processing Row 371: Latitude = 22.948388, Longitude = 81.297343 ...
# ✅ Success: Speed = 52.13 mm/yr, Azimuth = 48.3°
#
# 📍 Processing Row 372: Latitude = 22.953445, Longitude = 81.302802 ...
# ✅ Success: Speed = 52.13 mm/yr, Azimuth = 48.3°
#
# 📍 Processing Row 373: Latitude = 22.954975, Longitude = 81.303718 ...
# ✅ Success: Speed = 52.13 mm/yr, Azimuth = 48.3°
#
# 📍 Processing Row 374: Latitude = 22.958763, Longitude = 81.304189 ...
# ✅ Success: Speed = 52.13 mm/yr, Azimuth = 48.3°
#
# 📍 Processing Row 375: Latitude = 22.888881, Longitude = 81.304262 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 376: Latitude = 22.893830, Longitude = 81.312029 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 377: Latitude = 22.901549, Longitude = 81.309732 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 378: Latitude = 22.905741, Longitude = 81.311123 ...
# ✅ Success: Speed = 52.14 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 379: Latitude = 22.903661, Longitude = 81.310084 ...
# ✅ Success: Speed = 52.14 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 380: Latitude = 22.893737, Longitude = 81.315062 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 381: Latitude = 22.894161, Longitude = 81.316658 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 382: Latitude = 22.894125, Longitude = 81.318062 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 383: Latitude = 22.903274, Longitude = 81.320477 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 384: Latitude = 22.898537, Longitude = 81.318989 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 385: Latitude = 22.882796, Longitude = 81.271621 ...
# ✅ Success: Speed = 52.14 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 386: Latitude = 22.869328, Longitude = 81.277864 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.32°
#
# 📍 Processing Row 387: Latitude = 22.865742, Longitude = 81.275701 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 388: Latitude = 22.862666, Longitude = 81.274574 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 389: Latitude = 22.853111, Longitude = 81.269547 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 390: Latitude = 22.846150, Longitude = 81.265106 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 391: Latitude = 22.840479, Longitude = 81.262334 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 392: Latitude = 22.843324, Longitude = 81.263779 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 393: Latitude = 22.850926, Longitude = 81.269265 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 394: Latitude = 22.856748, Longitude = 81.267006 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 395: Latitude = 22.859011, Longitude = 81.268758 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 396: Latitude = 22.859436, Longitude = 81.270669 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 397: Latitude = 22.849564, Longitude = 81.262556 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 398: Latitude = 22.839902, Longitude = 81.244259 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 399: Latitude = 22.842627, Longitude = 81.252672 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 400: Latitude = 22.841983, Longitude = 81.231846 ...
# ✅ Success: Speed = 52.14 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 401: Latitude = 22.837137, Longitude = 81.240646 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# 📍 Processing Row 402: Latitude = 22.825248, Longitude = 81.247977 ...
# ✅ Success: Speed = 52.15 mm/yr, Azimuth = 48.33°
#
# ...
# ✅ Success: Speed = 51.5 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 3111: Latitude = 23.026358, Longitude = 78.873061 ...
# ✅ Success: Speed = 51.5 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 3112: Latitude = 23.026342, Longitude = 78.875840 ...
# ✅ Success: Speed = 51.5 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 3113: Latitude = 23.028038, Longitude = 78.868744 ...
# ✅ Success: Speed = 51.5 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 3114: Latitude = 23.018837, Longitude = 78.872314 ...
# ✅ Success: Speed = 51.5 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 3115: Latitude = 23.026753, Longitude = 78.828089 ...
# ✅ Success: Speed = 51.49 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3116: Latitude = 23.025674, Longitude = 78.830864 ...
# ✅ Success: Speed = 51.49 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3117: Latitude = 22.999563, Longitude = 78.834196 ...
# ✅ Success: Speed = 51.5 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 3118: Latitude = 23.014182, Longitude = 78.835806 ...
# ✅ Success: Speed = 51.49 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 3119: Latitude = 22.952403, Longitude = 78.846843 ...
# ✅ Success: Speed = 51.52 mm/yr, Azimuth = 48.11°
#
# 📍 Processing Row 3120: Latitude = 22.989333, Longitude = 78.833870 ...
# ✅ Success: Speed = 51.5 mm/yr, Azimuth = 48.1°
#
# 📍 Processing Row 3121: Latitude = 23.077429, Longitude = 78.762060 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3122: Latitude = 23.088164, Longitude = 78.806543 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3123: Latitude = 23.121215, Longitude = 78.893417 ...
# ✅ Success: Speed = 51.48 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3124: Latitude = 23.152314, Longitude = 78.800638 ...
# ✅ Success: Speed = 51.44 mm/yr, Azimuth = 48.04°
#
# 📍 Processing Row 3125: Latitude = 23.148929, Longitude = 78.960093 ...
# ✅ Success: Speed = 51.48 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 3126: Latitude = 23.143582, Longitude = 79.019663 ...
# ✅ Success: Speed = 51.5 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3127: Latitude = 23.154255, Longitude = 79.026665 ...
# ✅ Success: Speed = 51.5 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3128: Latitude = 23.156428, Longitude = 79.027468 ...
# ✅ Success: Speed = 51.5 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3129: Latitude = 23.164668, Longitude = 79.031690 ...
# ✅ Success: Speed = 51.5 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3130: Latitude = 23.162176, Longitude = 79.070744 ...
# ✅ Success: Speed = 51.51 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3131: Latitude = 23.169729, Longitude = 79.075835 ...
# ✅ Success: Speed = 51.51 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3132: Latitude = 23.176004, Longitude = 79.082874 ...
# ✅ Success: Speed = 51.51 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3133: Latitude = 23.178703, Longitude = 79.079804 ...
# ✅ Success: Speed = 51.51 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 3134: Latitude = 23.146613, Longitude = 79.007944 ...
# ✅ Success: Speed = 51.5 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3135: Latitude = 23.161418, Longitude = 78.954292 ...
# ✅ Success: Speed = 51.48 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 3136: Latitude = 23.168645, Longitude = 78.950587 ...
# ✅ Success: Speed = 51.48 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 3137: Latitude = 23.129736, Longitude = 78.892278 ...
# ✅ Success: Speed = 51.47 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3138: Latitude = 23.000474, Longitude = 78.589705 ...
# ✅ Success: Speed = 51.43 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3139: Latitude = 22.994226, Longitude = 78.591124 ...
# ✅ Success: Speed = 51.44 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3140: Latitude = 22.981819, Longitude = 78.592825 ...
# ✅ Success: Speed = 51.44 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3141: Latitude = 22.999822, Longitude = 78.586732 ...
# ✅ Success: Speed = 51.43 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3142: Latitude = 23.010972, Longitude = 78.604925 ...
# ✅ Success: Speed = 51.44 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3143: Latitude = 23.011717, Longitude = 78.605017 ...
# ✅ Success: Speed = 51.44 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3144: Latitude = 23.010173, Longitude = 78.604918 ...
# ✅ Success: Speed = 51.44 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3145: Latitude = 23.006911, Longitude = 78.606973 ...
# ✅ Success: Speed = 51.44 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3146: Latitude = 23.006329, Longitude = 78.607940 ...
# ✅ Success: Speed = 51.44 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3147: Latitude = 23.005733, Longitude = 78.611735 ...
# ✅ Success: Speed = 51.44 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3148: Latitude = 23.004760, Longitude = 78.614030 ...
# ✅ Success: Speed = 51.44 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3149: Latitude = 23.000559, Longitude = 78.615685 ...
# ✅ Success: Speed = 51.44 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3150: Latitude = 22.989764, Longitude = 78.616076 ...
# ✅ Success: Speed = 51.45 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3151: Latitude = 22.972193, Longitude = 78.626961 ...
# ✅ Success: Speed = 51.45 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 3152: Latitude = 22.968822, Longitude = 78.627751 ...
# ✅ Success: Speed = 51.45 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 3153: Latitude = 22.984235, Longitude = 78.632876 ...
# ✅ Success: Speed = 51.45 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3154: Latitude = 22.896946, Longitude = 78.233709 ...
# ✅ Success: Speed = 51.37 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3155: Latitude = 22.901484, Longitude = 78.239975 ...
# ✅ Success: Speed = 51.38 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3156: Latitude = 22.921659, Longitude = 78.270549 ...
# ✅ Success: Speed = 51.38 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3157: Latitude = 22.922837, Longitude = 78.272869 ...
# ✅ Success: Speed = 51.38 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3158: Latitude = 22.936754, Longitude = 78.288482 ...
# ✅ Success: Speed = 51.38 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3159: Latitude = 22.969689, Longitude = 78.312895 ...
# ✅ Success: Speed = 51.37 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3160: Latitude = 22.974791, Longitude = 78.318332 ...
# ✅ Success: Speed = 51.37 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3161: Latitude = 22.978011, Longitude = 78.321095 ...
# ✅ Success: Speed = 51.37 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3162: Latitude = 22.982527, Longitude = 78.323691 ...
# ✅ Success: Speed = 51.37 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3163: Latitude = 23.038987, Longitude = 78.405613 ...
# ✅ Success: Speed = 51.38 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 3164: Latitude = 23.103733, Longitude = 78.399686 ...
# ✅ Success: Speed = 51.35 mm/yr, Azimuth = 48.03°
#
# 📍 Processing Row 3165: Latitude = 23.056426, Longitude = 78.732062 ...
# ✅ Success: Speed = 51.45 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3166: Latitude = 23.055474, Longitude = 78.728770 ...
# ✅ Success: Speed = 51.45 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3167: Latitude = 23.057387, Longitude = 78.712186 ...
# ✅ Success: Speed = 51.45 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3168: Latitude = 23.058043, Longitude = 78.712137 ...
# ✅ Success: Speed = 51.45 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3169: Latitude = 23.039196, Longitude = 78.714245 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3170: Latitude = 23.024143, Longitude = 78.723035 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3171: Latitude = 23.033258, Longitude = 78.714686 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3172: Latitude = 23.030260, Longitude = 78.721240 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3173: Latitude = 23.029709, Longitude = 78.729615 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3174: Latitude = 23.044157, Longitude = 78.735512 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3175: Latitude = 23.044123, Longitude = 78.736062 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3176: Latitude = 23.042288, Longitude = 78.742482 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3177: Latitude = 23.040926, Longitude = 78.743499 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3178: Latitude = 23.042201, Longitude = 78.734657 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3179: Latitude = 22.907512, Longitude = 78.201153 ...
# ✅ Success: Speed = 51.36 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3180: Latitude = 22.914558, Longitude = 78.198080 ...
# ✅ Success: Speed = 51.36 mm/yr, Azimuth = 48.08°
#
# 📍 Processing Row 3181: Latitude = 22.924408, Longitude = 78.203661 ...
# ✅ Success: Speed = 51.36 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3182: Latitude = 22.927955, Longitude = 78.205509 ...
# ✅ Success: Speed = 51.36 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3183: Latitude = 22.950377, Longitude = 78.206300 ...
# ✅ Success: Speed = 51.35 mm/yr, Azimuth = 48.07°
#
# 📍 Processing Row 3184: Latitude = 22.970901, Longitude = 78.204579 ...
# ✅ Success: Speed = 51.34 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3185: Latitude = 22.983345, Longitude = 78.208459 ...
# ✅ Success: Speed = 51.34 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3186: Latitude = 22.985856, Longitude = 78.212519 ...
# ✅ Success: Speed = 51.34 mm/yr, Azimuth = 48.06°
#
# 📍 Processing Row 3187: Latitude = 22.990847, Longitude = 78.214546 ...
# ✅ Success: Speed = 51.34 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 3188: Latitude = 22.998375, Longitude = 78.213481 ...
# ✅ Success: Speed = 51.34 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 3189: Latitude = 23.004130, Longitude = 78.214587 ...
# ✅ Success: Speed = 51.34 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 3190: Latitude = 23.006142, Longitude = 78.216560 ...
# ✅ Success: Speed = 51.34 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 3191: Latitude = 23.024216, Longitude = 78.229156 ...
# ✅ Success: Speed = 51.33 mm/yr, Azimuth = 48.04°
#
# 📍 Processing Row 3192: Latitude = 23.036134, Longitude = 78.222918 ...
# ✅ Success: Speed = 51.33 mm/yr, Azimuth = 48.04°
#
# 📍 Processing Row 3193: Latitude = 23.043127, Longitude = 78.215344 ...
# ✅ Success: Speed = 51.32 mm/yr, Azimuth = 48.04°
#
# 📍 Processing Row 3194: Latitude = 23.053038, Longitude = 78.210407 ...
# ✅ Success: Speed = 51.32 mm/yr, Azimuth = 48.03°
#
# 📍 Processing Row 3195: Latitude = 23.074941, Longitude = 78.167734 ...
# ✅ Success: Speed = 51.3 mm/yr, Azimuth = 48.02°
#
# 📍 Processing Row 3196: Latitude = 23.074048, Longitude = 78.169001 ...
# ✅ Success: Speed = 51.3 mm/yr, Azimuth = 48.02°
#
# 📍 Processing Row 3197: Latitude = 23.072631, Longitude = 78.183653 ...
# ✅ Success: Speed = 51.31 mm/yr, Azimuth = 48.03°
#
# 📍 Processing Row 3198: Latitude = 23.073105, Longitude = 78.181864 ...
# ✅ Success: Speed = 51.31 mm/yr, Azimuth = 48.03°
#
# 📍 Processing Row 3199: Latitude = 23.067865, Longitude = 78.189413 ...
# ✅ Success: Speed = 51.31 mm/yr, Azimuth = 48.03°
#
# 📍 Processing Row 3200: Latitude = 23.067226, Longitude = 78.193046 ...
# ✅ Success: Speed = 51.31 mm/yr, Azimuth = 48.03°
#
# 📍 Processing Row 3201: Latitude = 23.046518, Longitude = 78.214110 ...
# ✅ Success: Speed = 51.32 mm/yr, Azimuth = 48.04°
#
# 📍 Processing Row 3202: Latitude = 22.999134, Longitude = 78.193102 ...
# ✅ Success: Speed = 51.33 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 3203: Latitude = 23.005478, Longitude = 78.179541 ...
# ✅ Success: Speed = 51.33 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 3204: Latitude = 23.006553, Longitude = 78.220458 ...
# ✅ Success: Speed = 51.34 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 3205: Latitude = 23.006546, Longitude = 78.223113 ...
# ✅ Success: Speed = 51.34 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 3206: Latitude = 23.010664, Longitude = 78.224311 ...
# ✅ Success: Speed = 51.34 mm/yr, Azimuth = 48.05°
#
# 📍 Processing Row 3207: Latitude = 23.044396, Longitude = 78.110972 ...
# ✅ Success: Speed = 51.3 mm/yr, Azimuth = 48.03°
#
# 📍 Processing Row 3208: Latitude = 23.040958, Longitude = 78.094308 ...
# ✅ Success: Speed = 51.29 mm/yr, Azimuth = 48.03°
#
# 📍 Processing Row 3209: Latitude = 23.142709, Longitude = 78.398359 ...
# ✅ Success: Speed = 51.34 mm/yr, Azimuth = 48.02°
#
# 📍 Processing Row 3210: Latitude = 22.841739, Longitude = 78.259321 ...
# ✅ Success: Speed = 51.4 mm/yr, Azimuth = 48.1°
#
# 📍 Processing Row 3211: Latitude = 22.848821, Longitude = 78.269802 ...
# ✅ Success: Speed = 51.4 mm/yr, Azimuth = 48.1°
#
# 📍 Processing Row 3212: Latitude = 22.851484, Longitude = 78.275600 ...
# ✅ Success: Speed = 51.4 mm/yr, Azimuth = 48.1°
#
# 📍 Processing Row 3213: Latitude = 22.862102, Longitude = 78.275642 ...
# ✅ Success: Speed = 51.4 mm/yr, Azimuth = 48.1°
#
# 📍 Processing Row 3214: Latitude = 22.851146, Longitude = 78.283462 ...
# ✅ Success: Speed = 51.4 mm/yr, Azimuth = 48.1°
#
# 📍 Processing Row 3215: Latitude = 22.759496, Longitude = 78.291835 ...
# ✅ Success: Speed = 51.43 mm/yr, Azimuth = 48.13°
#
# 📍 Processing Row 3216: Latitude = 22.746862, Longitude = 78.289849 ...
# ✅ Success: Speed = 51.44 mm/yr, Azimuth = 48.13°
#
# 📍 Processing Row 3217: Latitude = 22.720848, Longitude = 78.299658 ...
# ✅ Success: Speed = 51.45 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 3218: Latitude = 22.666155, Longitude = 78.315463 ...
# ✅ Success: Speed = 51.47 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 3219: Latitude = 22.659483, Longitude = 78.318162 ...
# ✅ Success: Speed = 51.47 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 3220: Latitude = 22.657835, Longitude = 78.322433 ...
# ✅ Success: Speed = 51.47 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 3221: Latitude = 22.648657, Longitude = 78.325748 ...
# ✅ Success: Speed = 51.48 mm/yr, Azimuth = 48.17°
#
# 📍 Processing Row 3222: Latitude = 22.769248, Longitude = 78.298726 ...
# ✅ Success: Speed = 51.43 mm/yr, Azimuth = 48.13°
#
# 📍 Processing Row 3223: Latitude = 22.721336, Longitude = 78.337030 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 3224: Latitude = 22.714599, Longitude = 78.336677 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 3225: Latitude = 22.687449, Longitude = 78.351568 ...
# ✅ Success: Speed = 51.47 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 3226: Latitude = 22.677460, Longitude = 78.360088 ...
# ✅ Success: Speed = 51.48 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 3227: Latitude = 22.668311, Longitude = 78.360549 ...
# ✅ Success: Speed = 51.48 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 3228: Latitude = 22.666280, Longitude = 78.363534 ...
# ✅ Success: Speed = 51.48 mm/yr, Azimuth = 48.16°
#
# 📍 Processing Row 3229: Latitude = 22.724453, Longitude = 78.336178 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 3230: Latitude = 22.803333, Longitude = 78.325698 ...
# ✅ Success: Speed = 51.43 mm/yr, Azimuth = 48.12°
#
# 📍 Processing Row 3231: Latitude = 22.800903, Longitude = 78.327678 ...
# ✅ Success: Speed = 51.43 mm/yr, Azimuth = 48.12°
#
# 📍 Processing Row 3232: Latitude = 22.785096, Longitude = 78.342946 ...
# ✅ Success: Speed = 51.44 mm/yr, Azimuth = 48.13°
#
# 📍 Processing Row 3233: Latitude = 22.737398, Longitude = 78.361581 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 3234: Latitude = 22.735209, Longitude = 78.360099 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 3235: Latitude = 22.730708, Longitude = 78.365658 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.14°
#
# 📍 Processing Row 3236: Latitude = 22.716343, Longitude = 78.381975 ...
# ✅ Success: Speed = 51.47 mm/yr, Azimuth = 48.15°
#
# 📍 Processing Row 3237: Latitude = 22.987140, Longitude = 78.676684 ...
# ✅ Success: Speed = 51.46 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 3238: Latitude = 22.974163, Longitude = 78.684954 ...
# ✅ Success: Speed = 51.47 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 3239: Latitude = 22.971047, Longitude = 78.686848 ...
# ✅ Success: Speed = 51.47 mm/yr, Azimuth = 48.09°
#
# 📍 Processing Row 3240: Latitude = 22.957888, Longitude = 78.710803 ...
# ✅ Success: Speed = 51.48 mm/yr, Azimuth = 48.1°
#
# 📍 Processing Row 3241: Latitude = 22.785167, Longitude = 78.840737 ...
# ✅ Success: Speed = 51.57 mm/yr, Azimuth = 48.16°
#
# ✅ All done! Results saved to:
# C:\Users\mainw\Downloads\GAGE_Output.xlsx
